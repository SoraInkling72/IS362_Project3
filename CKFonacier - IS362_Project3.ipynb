# %% [markdown]
# # **IS 362 - Project 3**

# %%
import sqlalchemy as sqla
import pandas as pd

sql = '''SELECT LastName, FirstName
         FROM Customer
         ORDER BY LastName, FirstName'''

db = sqla.create_engine('sqlite:///Chinook_Sqlite.sqlite')
pd.read_sql(sql, db)
# Out:
#         LastName  FirstName
# 0        Almeida    Roberto
# 1        Barnett      Julia
# 2        Bernard    Camille
# 3         Brooks   Michelle
# 4          Brown     Robert
# 5          Chase      Kathy
# 6     Cunningham    Richard
# 7         Dubois       Marc
# 8      Fernandes       João
# 9        Francis     Edward
# 10        Girard      Wyatt
# 11     Gonçalves       Luís
# 12        Gordon       John
# 13         Goyer        Tim
# 14          Gray    Patrick
# 15        Gruber     Astrid
# 16     Gutiérrez      Diego
# 17        Hansen      Bjørn
# 18        Harris      Frank
# 19          Holý     Helena
# 20        Hughes       Phil
# 21    Hämäläinen      Terhi
# 22     Johansson     Joakim
# 23         Jones       Emma
# 24        Kovács   Ladislav
# 25        Köhler     Leonie
# 26       Leacock    Heather
# 27      Lefebvre  Dominique
# 28       Mancini      Lucas
# 29       Martins    Eduardo
# 30       Mercier   Isabelle
# 31        Miller        Dan
# ...

# %% [markdown]
# In order to get the table required for the assignment, I would have to review my knowledge in SQL to join the information across five tables in the SQLite file to get the resulting DataFrame the way as intended.
#
# The pandas DataFrame is intended to display Customers’ Last Name and First Name, and each customer’s purchased Track names and Album Titles.
#
# The source of the SQLite file is this: https://github.com/lerocha/chinook-database/blob/master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite

# %%
music = '''SELECT Customer.LastName, Customer.FirstName, Track.Name, Album.Title FROM Customer
           JOIN Invoice
           ON Customer.CustomerId = Invoice.CustomerId
           JOIN InvoiceLine
           ON Invoice.InvoiceId = InvoiceLine.InvoiceID
           JOIN Track
           ON InvoiceLine.TrackId = Track.TrackId
           JOIN Album
           ON Track.AlbumId = Album.AlbumId
           JOIN Artist
           ON Album.ArtistId = Artist.ArtistId
           ORDER BY Customer.LastName, Customer.FirstName
           '''

pd.read_sql(music, db)
# Out:
#         LastName FirstName                                               Name  \
# 0        Almeida   Roberto                            Right Next Door to Hell
# 1        Almeida   Roberto                                     In The Evening
# 2        Almeida   Roberto                                   Fool In The Rain
# 3        Almeida   Roberto  Saudade Dos Aviões Da Panair (Conversando No Bar)
# 4        Almeida   Roberto                             Caso Você Queira Saber
# ...          ...       ...                                                ...
# 2235  Zimmermann      Fynn                                    Nothin' To Lose
# 2236  Zimmermann      Fynn                         Since I've Been Loving You
# 2237  Zimmermann      Fynn                                Going To California
# 2238  Zimmermann      Fynn                                 We're Gonna Groove
# 2239  Zimmermann      Fynn                                         Ozone Baby
#
# ...
